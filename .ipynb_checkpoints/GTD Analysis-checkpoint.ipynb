# %% [markdown]
# # Global Terrorism Database
#
# ## Introduction
# The aim of this analysis is to provide answers to the following questions:
#
# - How has the number of terrorist activities changed over the years?
# - Are there certain regions where this trend is different from the global averages?
# - How often the attack becomes a success?
# - What are the most common methods of attacks? Does it differ in various regions or in time?
#
# ## About the dataset
# The Dataset was extracted from the Global Terrorism Database (GTD) - an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks.
#
# ## Explanation of selected columns:
# - success - Success of a terrorist strike
# - suicide - 1 = "Yes" The incident was a suicide attack. 0 = "No" There is no indication that the incident was a suicide
# - attacktype1 - The general method of attack
# - attacktype1_txt - The general method of attack and broad class of tactics used.
# - targtype1_txt - The general type of target/victim
# - targsubtype1_txt - The more specific target category
# - target1 - The specific person, building, installation that was targeted and/or victimized
# - natlty1_txt - The nationality of the target that was attacked
# - gname - The name of the group that carried out the attack
# - gsubname - Additional details about group that carried out the attack like fractions
# - nperps - The total number of terrorists participating in the incident
# - weaptype1_txt - General type of weapon used in the incident
# - weapsubtype1_txt - More specific value for most of the Weapon Types
# - nkill - The number of total confirmed fatalities for the incident
# - nkillus - The number of U.S. citizens who died as a result of the incident

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, roc_curve, classification_report, precision_score, recall_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from xgboost import XGBClassifier

from sklearn.pipeline import make_pipeline

# %%
data1 = pd.read_csv('../gtd_data/globalterrorismdb_1.csv')
data_2021 = pd.read_csv('../gtd_data/globalterrorismdb_2021Jan-June_1222dist.csv')

# %%
data = pd.concat([data1, data_2021], ignore_index=True)

# %%
data.shape
# Out:
# (214666, 135)

# %%
# After combining the Data till 2021, We now have a total of 214666 rows and 135 columns

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
print('Number of Variables in dataset: ', data.shape[1])
# Out:
# Number of Variables in dataset:  135

# %%
print('Number of records in dataset: ', data.shape[0])
# Out:
# Number of records in dataset:  214666

# %%
data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### 1. Number of Terrorist Attacks per year

# %%
# Attacks per Year in whole world
attacks_per_year = data['iyear'].value_counts().sort_index()

# %%
plt.figure(figsize=(10, 8))
sns.countplot(data, x='iyear')
plt.title('Number of Terrorist Attacks per Year')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend()
#plt.savefig("attacks_per_year.png", dpi=300, bbox_inches='tight')  # Save high-resolution image
plt.show()

# %%
# Trend of Terrorist Attacks every Year
plt.figure(figsize=(12, 6))
plt.plot(attacks_per_year.index, attacks_per_year.values, marker='o', linestyle='-')
plt.title('Trend of Terrorist Attacks per Year')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.grid(True)
plt.legend()
#plt.savefig("attacks_per_year_Trend.png", dpi=300, bbox_inches='tight')  # Save high-resolution image
plt.show()

# %% [raw]
# Inference:
# As we can cleary see, that the number of Terrorist attacks have been increasing every year.
# In 2014, maximum number of attacks were happend since 1970. And they started reducing after 2014.

# %% [markdown]
# ### Different type of Attack Types

# %%
attack_types = data['attacktype1_txt'].value_counts().sort_values(ascending=False)
attack_types
# Out:
# attacktype1_txt
# Bombing/Explosion                      99986
# Armed Assault                          50845
# Assassination                          21989
# Hostage Taking (Kidnapping)            14493
# Facility/Infrastructure Attack         12606
# Unknown                                11545
# Unarmed Assault                         1257
# Hostage Taking (Barricade Incident)     1172
# Hijacking                                773
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 8))
attack_types.plot(kind='bar', color='red')
plt.title('Distribution of Attack Types')
plt.xlabel('Attack Types')
plt.ylabel('Number of Attacks')
plt.xticks(rotation=60)
plt.grid(axis='y')
plt.tight_layout()
plt.legend()
#plt.savefig("Attack_types_frequency.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Number of Attacks by Country

# %%
attacks_by_country = data['country_txt'].value_counts().sort_values(ascending=False)
attacks_by_country.head(15)
# Out:
# country_txt
# Iraq              28068
# Afghanistan       20373
# Pakistan          15654
# India             14164
# Colombia           8991
# Philippines        8375
# Yemen              6317
# Peru               6116
# Nigeria            5998
# United Kingdom     5553
# Somalia            5442
# El Salvador        5321
# Turkey             4499
# Thailand           4228
# Spain              3257
# Name: count, dtype: int64

# %%
# Number of Terrorist Attacks per country
plt.figure(figsize=(10, 8))
attacks_by_country.head(20).plot(kind='bar')
plt.title('Number of Terrorist Attacks per Country')
plt.xlabel('Country')
plt.ylabel('Number of Attacks')
plt.grid(axis='y')
plt.tight_layout()
plt.legend()
# plt.savefig("Attacks_per_country.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
from wordcloud import WordCloud
countries_effected = data['country_txt'].dropna()

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(countries_effected))

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Word Cloud for Countries effected in Terrorist Incidents')
plt.axis('off')
plt.tight_layout()
plt.legend()
# plt.savefig("CountryEffected_wordCloud.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Disrtribution of Target Types

# %%
target_types = data['targtype1_txt'].value_counts().sort_values(ascending=False)
target_types.head(10)
# Out:
# targtype1_txt
# Private Citizens & Property       53487
# Military                          35292
# Police                            29236
# Government (General)              24355
# Business                          22412
# Unknown                            7351
# Transportation                     7241
# Utilities                          6424
# Religious Figures/Institutions     5191
# Educational Institution            4836
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 8))
target_types.plot(kind='bar', color='orange')
plt.title('Distribution of Target Types')
plt.xlabel('Target Types')
plt.ylabel('Number of Attacks')
plt.xticks(rotation=90)
plt.legend()
# plt.savefig("TargetType_Distribution.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Number of people killed by Country

# %%
casualties_per_year = data.groupby('iyear')['nkill'].count().sort_index()
casualties_per_year
# Out:
# iyear
# 1970      609
# 1971      407
# 1972      523
# 1973      424
# 1974      523
# 1975      587
# 1976      814
# 1977     1191
# 1978     1373
# 1979     2257
# 1980     2210
# 1981     1928
# 1982     1741
# 1983     1974
# 1984     2805
# 1985     2474
# 1986     2481
# 1987     3089
# 1988     3688
# 1989     4290
# 1990     3880
# 1991     4581
# 1992     5048
# 1994     3368
# 1995     3076
# 1996     3001
# 1997     3131
# 1998      871
# 1999     1346
# 2000     1766
# 2001     1892
# 2002     1318
# 2003     1260
# 2004     1149
# 2005     1999
# 2006     2672
# 2007     3206
# 2008     4736
# 2009     4705
# 2010     4822
# 2011     5047
# 2012     8318
# 2013    11694
# 2014    15925
# 2015    14290
# 2016    13210
# 2017    10681
# 2018     9082
# 2019     7857
# 2020     7860
# 2021     4536
# Name: nkill, dtype: int64

# %%
# Number of people killed by country
plt.figure(figsize=(10, 8))
casualties_per_year.plot(kind='bar', color='red')
plt.title('Number of casualties per Country')
plt.xlabel('Year')
plt.ylabel('Number of Casualties')
plt.tight_layout()
plt.legend()
# plt.savefig("Number of people killed by country.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Number of Casualties by Target_types

# %%
casualties_by_attackType = data.groupby('attacktype1_txt')['nkill'].sum().sort_values(ascending=False)
casualties_by_attackType
# Out:
# attacktype1_txt
# Armed Assault                          186919.0
# Bombing/Explosion                      176655.0
# Unknown                                 50934.0
# Hostage Taking (Kidnapping)             33694.0
# Assassination                           28187.0
# Hostage Taking (Barricade Incident)      5102.0
# Facility/Infrastructure Attack           4664.0
# Hijacking                                3782.0
# Unarmed Assault                           956.0
# Name: nkill, dtype: float64

# %%
plt.figure(figsize=(12, 6))
casualties_by_attackType.plot(kind='bar')
plt.title('Number of Casualties by type of Attack')
plt.xlabel('Type of Attack')
plt.ylabel('Number of Casualties')
plt.grid(axis='y')
plt.legend()
# plt.savefig("Number_of_casualties_by_attackType.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Top Terrorist Groups by Casualties

# %%
top_terrorist_groups = data.groupby('gname')[['nkill', 'nwound']].sum().sort_values(by='nkill', ascending=False)
top_terrorist_groups
# Out:
#                                                        nkill    nwound
# gname
# Unknown                                             122086.0  222785.0
# Taliban                                              57650.0   47704.0
# Islamic State of Iraq and the Levant (ISIL)          43688.0   35182.0
# Boko Haram                                           26339.0   12204.0
# Al-Shabaab                                           12740.0   10215.0
# ...                                                      ...       ...
# Niger Delta Freedom Fighters (NDDF)                      0.0       0.0
# Niger Delta Forest Army (NDFA)                           0.0       0.0
# Cuban Secret Army                                        0.0       0.0
# Niger Armed Forces dissidents                            0.0       0.0
# uMkhonto we Sizwe Military Veterans Association...       0.0       0.0
#
# [3767 rows x 2 columns]

# %%
plt.figure(figsize=(12, 8))
top_terrorist_groups.head(20).plot(kind='bar')
plt.title('Top Terrorist Groups by Casualties')
plt.xlabel('Groups')
plt.ylabel('Number of people killed/wounded')
plt.xticks(rotation=90)
plt.legend()
# plt.savefig("Top_terrorist_groups_by_casualties.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Summarising EDA

# %% [markdown]
# ### 1. Top 5 Terrorist Groups (number of Attacks)

# %%
groups = data[data['gname'] != 'Unknown']
groups.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 5  197001010002   1970       1     1        NaN         0        NaN      217
# 6  197001020001   1970       1     2        NaN         0        NaN      218
# 8  197001020003   1970       1     2        NaN         0        NaN      217
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# 5       United States       1  ...
# 6             Uruguay       3  ...
# 8       United States       1  ...
#
#                                             addnotes  \
# 0                                                NaN
# 1                                                NaN
# 5  The Cairo Chief of Police, William Petersen, r...
# 6                                                NaN
# 8  The New Years Gang issue a communiqué to a loc...
#
#                                               scite1  \
# 0                                                NaN
# 1                                                NaN
# 5  "Police Chief Quits," Washington Post, January...
# 6                                                NaN
# 8  Tom Bates, "Rads: The 1970 Bombing of the Army...
#
#                                               scite2  \
# 0                                                NaN
# 1                                                NaN
# 5  "Cairo Police Chief Quits; Decries Local 'Mili...
# 6                                                NaN
# 8  David Newman, Sandra Sutherland, and Jon Stewa...
#
#                                               scite3        dbsource  INT_LOG  \
# 0                                                NaN            PGIS        0
# 1                                                NaN            PGIS        0
# 5  Christopher Hewitt, "Political Violence and Te...  Hewitt Project       -9
# 6                                                NaN            PGIS        0
# 8  The Wisconsin Cartographers' Guild, "Wisconsin...  Hewitt Project        0
#
#    INT_IDEO INT_MISC INT_ANY  related
# 0         0        0       0      NaN
# 1         1        1       1      NaN
# 5        -9        0      -9      NaN
# 6         0        0       0      NaN
# 8         0        0       0      NaN
#
# [5 rows x 135 columns]

# %%
top_10_terrorist_groups = (data['gname'].value_counts(normalize=True)*100).sort_values(ascending=False)
top_10_terrorist_groups.head(10)
# Out:
# gname
# Unknown                                             43.637558
# Taliban                                              6.026106
# Islamic State of Iraq and the Levant (ISIL)          3.484017
# Shining Path (SL)                                    2.127491
# Al-Shabaab                                           2.118174
# Houthi extremists (Ansar Allah)                      1.637893
# Boko Haram                                           1.611340
# New People's Army (NPA)                              1.602955
# Farabundo Marti National Liberation Front (FMLN)     1.561030
# Irish Republican Army (IRA)                          1.243793
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(12, 6))
top_10_terrorist_groups.head(10).plot(kind='bar')
plt.title('Top 10 Terroriest Groups by number of Attacks')
plt.xlabel('Groups')
plt.ylabel('Number of Attacks')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## 2. Top 10 Countries most affected by Terrorist Attacks

# %%
top_10_country = data['country_txt'].value_counts().head(10)
top_10_country
# Out:
# country_txt
# Iraq              28068
# Afghanistan       20373
# Pakistan          15654
# India             14164
# Colombia           8991
# Philippines        8375
# Yemen              6317
# Peru               6116
# Nigeria            5998
# United Kingdom     5553
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
# top_10_country.plot(kind='bar')
sns.countplot(data, x='country_txt', order=top_10_country.index, palette='magma')
plt.title('Top 10 most affected Countries')
plt.xlabel('Country')
plt.ylabel('Number of Attacks')
plt.grid(axis='y')
plt.legend()
# plt.savefig("Top10_countries_most_affected.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 3. Top 10 most common attack types

# %%
top_10_attack_types = data['attacktype1_txt'].value_counts().head(10)
top_10_attack_types
# Out:
# attacktype1_txt
# Bombing/Explosion                      99986
# Armed Assault                          50845
# Assassination                          21989
# Hostage Taking (Kidnapping)            14493
# Facility/Infrastructure Attack         12606
# Unknown                                11545
# Unarmed Assault                         1257
# Hostage Taking (Barricade Incident)     1172
# Hijacking                                773
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
top_10_attack_types.plot(kind='bar')
plt.title('Top 10 most common Attack Types')
plt.xlabel('Attack Types')
plt.ylabel('Number of attacks')
plt.grid(axis='y')
plt.legend()
# plt.savefig("Top10_most_common_attackTypes.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 4. Top 10 most common Target Types

# %%
top_10_target_types = data['targtype1_txt'].value_counts().head(10)
top_10_target_types
# Out:
# targtype1_txt
# Private Citizens & Property       53487
# Military                          35292
# Police                            29236
# Government (General)              24355
# Business                          22412
# Unknown                            7351
# Transportation                     7241
# Utilities                          6424
# Religious Figures/Institutions     5191
# Educational Institution            4836
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
top_10_target_types.plot(kind='bar')
plt.title('Top 10 most common Attack types')
plt.xlabel('Attack Types')
plt.ylabel('Number of Attacks')
plt.grid(axis='y')
plt.legend()
# plt.savefig("Top10_most_common_attackTypes.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 5. Number of Attacks per year

# %%
print('Number of Attacks per Year: \n')
print(attacks_per_year)
# Out:
# Number of Attacks per Year:
#
# iyear
# 1970      651
# 1971      471
# 1972      567
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2661
# 1981     2586
# 1982     2543
# 1983     2870
# 1984     3495
# 1985     2914
# 1986     2860
# 1987     3183
# 1988     3720
# 1989     4324
# 1990     3886
# 1991     4685
# 1992     5071
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3198
# 1998      934
# 1999     1396
# 2000     1823
# 2001     1912
# 2002     1330
# 2003     1280
# 2004     1164
# 2005     2017
# 2006     2757
# 2007     3250
# 2008     4801
# 2009     4723
# 2010     4827
# 2011     5075
# 2012     8525
# 2013    12047
# 2014    16960
# 2015    15138
# 2016    14051
# 2017    11364
# 2018     9853
# 2019     8537
# 2020     8438
# 2021     4960
# Name: count, dtype: int64

# %% [markdown]
# ## 6. Most 10 most affected Regions of the World

# %%
top_10_region = data['region_txt'].value_counts().head(10)
top_10_region
# Out:
# region_txt
# Middle East & North Africa     59514
# South Asia                     56578
# Sub-Saharan Africa             24883
# South America                  19993
# Western Europe                 17433
# Southeast Asia                 14871
# Central America & Caribbean    10388
# Eastern Europe                  5342
# North America                   3906
# East Asia                        852
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
# top_10_region.plot(kind='bar')
sns.countplot(data, x='region_txt', order=top_10_region.index)
plt.title('Top 10 Most Affected Regions of the World')
plt.xlabel('Region')
plt.ylabel('Number of Attacks')
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.legend()
# plt.savefig("Top10_most_affected_regions_of_world.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Check for Duplicates

# %%
data.duplicated().sum()
# Out:
# 0

# %%
# No duplicate values

# %% [markdown]
# ### Null values check

# %%
null_values = data.isnull().sum().sort_values(ascending=False)
null_df = pd.DataFrame(null_values, index=None, columns=['Null Count'])

# %%
# Null values greater than zero
greater_than_zero = null_df[null_df['Null Count'] > 0]
null_var = len(greater_than_zero)
print(null_var, 'Variables with Null Values')
# Out:
# 104 Variables with Null Values

# %%
null_df.reset_index(inplace=True)
null_df = null_df.rename(columns={'index': 'Variables'})
null_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Variables   135 non-null    object
#  1   Null Count  135 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
null_df[null_df['Null Count']>0]
# Out:
#             Variables  Null Count
# 0           gsubname3      214643
# 1        weapsubtype4      214596
# 2    weapsubtype4_txt      214596
# 3           weaptype4      214593
# 4       weaptype4_txt      214593
# ..                ...         ...
# 99               city         427
# 100       guncertain1         380
# 101         ishostkid         178
# 102          multiple           3
# 103       specificity           1
#
# [104 rows x 2 columns]

# %%
# Calculating percent missing and percent complete
null_df['percent_missing'] = null_df['Null Count']/(len(data))
null_df['percent_complete'] = 1-null_df['percent_missing']

perc_complete = 0.95
selected_attributes = null_df[null_df['percent_complete'] >= perc_complete]
print(len(selected_attributes), f'Attributes have a percent complete >= {int(perc_complete*100)}%')
# Out:
# 41 Attributes have a percent complete >= 95%

# %%
selected_attributes.reset_index()
# Out:
#     index        Variables  Null Count  percent_missing  percent_complete
# 0      94        longitude        4727         0.022020          0.977980
# 1      95         latitude        4726         0.022016          0.977984
# 2      96          natlty1        2074         0.009662          0.990338
# 3      97      natlty1_txt        2074         0.009662          0.990338
# 4      98          target1         637         0.002967          0.997033
# 5      99             city         427         0.001989          0.998011
# 6     100      guncertain1         380         0.001770          0.998230
# 7     101        ishostkid         178         0.000829          0.999171
# 8     102         multiple           3         0.000014          0.999986
# 9     103      specificity           1         0.000005          0.999995
# 10    104            crit1           0         0.000000          1.000000
# 11    105       individual           0         0.000000          1.000000
# 12    106         extended           0         0.000000          1.000000
# 13    107             iday           0         0.000000          1.000000
# 14    108           imonth           0         0.000000          1.000000
# 15    109    targtype1_txt           0         0.000000          1.000000
# 16    110            gname           0         0.000000          1.000000
# 17    111            iyear           0         0.000000          1.000000
# 18    112      country_txt           0         0.000000          1.000000
# 19    113         dbsource           0         0.000000          1.000000
# 20    114          INT_LOG           0         0.000000          1.000000
# 21    115         INT_IDEO           0         0.000000          1.000000
# 22    116         INT_MISC           0         0.000000          1.000000
# 23    117          INT_ANY           0         0.000000          1.000000
# 24    118          country           0         0.000000          1.000000
# 25    119       region_txt           0         0.000000          1.000000
# 26    120           region           0         0.000000          1.000000
# 27    121            crit2           0         0.000000          1.000000
# 28    122        provstate           0         0.000000          1.000000
# 29    123        targtype1           0         0.000000          1.000000
# 30    124        weaptype1           0         0.000000          1.000000
# 31    125    weaptype1_txt           0         0.000000          1.000000
# 32    126  attacktype1_txt           0         0.000000          1.000000
# 33    127         vicinity           0         0.000000          1.000000
# 34    128      attacktype1           0         0.000000          1.000000
# 35    129          suicide           0         0.000000          1.000000
# 36    130          success           0         0.000000          1.000000
# 37    131        doubtterr           0         0.000000          1.000000
# 38    132         property           0         0.000000          1.000000
# 39    133            crit3           0         0.000000          1.000000
# 40    134          eventid           0         0.000000          1.000000

# %%
selected_attributes_list = selected_attributes['Variables'].to_list()
data_cleaned = data.loc[:, data.columns.isin(selected_attributes_list)]
print(data_cleaned.shape)
print(data_cleaned.columns.values)
# Out:
# (214666, 41)
# ['eventid' 'iyear' 'imonth' 'iday' 'extended' 'country' 'country_txt'
#  'region' 'region_txt' 'provstate' 'city' 'latitude' 'longitude'
#  'specificity' 'vicinity' 'crit1' 'crit2' 'crit3' 'doubtterr' 'multiple'
#  'success' 'suicide' 'attacktype1' 'attacktype1_txt' 'targtype1'
#  'targtype1_txt' 'target1' 'natlty1' 'natlty1_txt' 'gname' 'guncertain1'
#  'individual' 'weaptype1' 'weaptype1_txt' 'property' 'ishostkid'
#  'dbsource' 'INT_LOG' 'INT_IDEO' 'INT_MISC' 'INT_ANY']

# %%
plt.figure(figsize=(25, 22))
sns.heatmap(data_cleaned.corr(numeric_only=True), annot=True, cmap='RdBu', vmin=-1)
plt.legend()
# plt.savefig("Correlation_check.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
corr_matrix = data_cleaned.select_dtypes(np.number).corr()

# %%
high_corr = corr_matrix.where((corr_matrix > 0.5) & (corr_matrix < 1.0))

high_corr_pairs = high_corr.stack().reset_index()
high_corr_pairs.columns = ['Feature_1', 'Feature_2', 'Correlation']
high_corr_pairs = high_corr_pairs.sort_values(by='Correlation', ascending=False)

print('Highly correlated feature pairs (0.5 < corr < 1.0)')
print(high_corr_pairs)
# Out:
# Highly correlated feature pairs (0.5 < corr < 1.0)
#       Feature_1    Feature_2  Correlation
# 0       eventid        iyear     0.999996
# 2         iyear      eventid     0.999996
# 10      INT_LOG     INT_IDEO     0.996426
# 12     INT_IDEO      INT_LOG     0.996426
# 13     INT_IDEO      INT_ANY     0.899411
# 15      INT_ANY     INT_IDEO     0.899411
# 11      INT_LOG      INT_ANY     0.896726
# 14      INT_ANY      INT_LOG     0.896726
# 7   attacktype1    weaptype1     0.698660
# 9     weaptype1  attacktype1     0.698660
# 4       country      natlty1     0.634821
# 8       natlty1      country     0.634821
# 1       eventid    longitude     0.524264
# 5     longitude      eventid     0.524264
# 3         iyear    longitude     0.524248
# 6     longitude        iyear     0.524248

# %% [raw]
# Inference:
#     These are the columns which are highly correlated with each other.
#     The best method is to drop these columns to remove multicolinearity.
#     So, that our models are less affected by them.

# %%
corr_df = pd.DataFrame(high_corr_pairs)
corr_df.reset_index(inplace=True)

drop_list = set()

for var1, var2 in zip(corr_df['Feature_1'], corr_df['Feature_1']):
    drop_list.add(var1)
    drop_list.add(var2)

drop_list
# Out:
# {'INT_ANY',
#  'INT_IDEO',
#  'INT_LOG',
#  'attacktype1',
#  'country',
#  'eventid',
#  'iyear',
#  'longitude',
#  'natlty1',
#  'weaptype1'}

# %%
# Remove correlated columns from the dataset
data_cleaned = data_cleaned.drop(labels=drop_list, axis=1)
data_cleaned.columns
# Out:
# Index(['imonth', 'iday', 'extended', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'specificity', 'vicinity', 'crit1',
#        'crit2', 'crit3', 'doubtterr', 'multiple', 'success', 'suicide',
#        'attacktype1_txt', 'targtype1', 'targtype1_txt', 'target1',
#        'natlty1_txt', 'gname', 'guncertain1', 'individual', 'weaptype1_txt',
#        'property', 'ishostkid', 'dbsource', 'INT_MISC'],
#       dtype='object')

# %%
len(data_cleaned.columns)
# Out:
# 31

# %% [raw]
# In exploring dbsource column closer, this column does not seem relevent to the
# modeling process as it simply the database source, We can drop it

# %%
data_cleaned = data_cleaned.drop(labels=['dbsource'], axis=1)

# %% [raw]
# Before building the models:
# 1. Evaluate the target variable
# 2. Identify the groups that are responsible for more than the avg number of attacks accross all groups
# 3. Remove rows in the data where the groups below this threshold are located
# 4. Remove rows in the data where the gname is unknown
#
# So that we only train the model using the confirmed and active groups in attacks

# %%
gname_breakdown = data_cleaned.groupby('gname')[['gname']].count().rename(columns={'gname': 'count'})
gname_total = gname_breakdown.index
gname_above_avg = gname_breakdown[gname_breakdown['count'] > gname_breakdown['count'].mean() ]

print('Total Groups: ', len(gname_total))
print('Count of groups responsible for more than the Average attacks: ', len(gname_above_avg))
# Out:
# Total Groups:  3767
# Count of groups responsible for more than the Average attacks:  218

# %%
# Cut data_cleaned to include only selected groups
gname_above_avg_list = gname_above_avg.index.to_list()
data_cleaned = data_cleaned[data_cleaned['gname'].isin(gname_above_avg_list)]

# Records where group name is Unknown, Storing them in another dataframe
X_test_final = data_cleaned[data_cleaned['gname']=='Unknown'] # 45%

# %%
# View info on target after removal
gname_breakdown = data_cleaned.groupby(['gname'])[['gname']].count().rename(columns={'gname':'count'})
gname_total = gname_breakdown.index

# %%
print('Total groups in new dataset: ', len(gname_total))
print('\n', 'Total number of records after processing: ', len(data_cleaned))
# Out:
# Total groups in new dataset:  218
#
#  Total number of records after processing:  198005

# %%
gname_breakdown = data_cleaned.groupby('gname')[['gname']].count().rename(columns={'gname': 'count'})
gname_breakdown
# Out:
#                                              count
# gname
# Abu Sayyaf Group (ASG)                         595
# Adan-Abyan Province of the Islamic State        57
# African National Congress (South Africa)       607
# Al-Aqsa Martyrs Brigade                        178
# Al-Gama'at al-Islamiyya (IG)                   259
# ...                                            ...
# United Liberation Front of Assam (ULFA)        394
# United Popular Action Movement                 109
# United Self Defense Units of Colombia (AUC)     68
# Unknown                                      93675
# White supremacists/nationalists                153
#
# [218 rows x 1 columns]

# %%
# Remove records where gname is 'Unknown'
# Cut data_cleaned 
g_list = gname_breakdown.index.to_list()
g_list.remove('Unknown')

# %%
data_cleaned = data_cleaned[data_cleaned['gname'].isin(g_list)]
print("Total number of records after removing 'unknown' groups: ", len(data_cleaned))
# Out:
# Total number of records after removing 'unknown' groups:  104330

# %% [markdown]
# ## Handle Categorical Variables

# %%
# view levels of each categorical variable
    # Only those with levels <30 will be included (ensures python doesn't crash in OneHotEncoding)

cat_vars = data_cleaned.loc[:, data_cleaned.dtypes == object]
cat_vars_count = cat_vars.nunique()
cat_vars_count
# Out:
# country_txt          147
# region_txt            12
# provstate           1464
# city               29028
# attacktype1_txt        9
# targtype1_txt         22
# target1            43178
# natlty1_txt          173
# gname                217
# weaptype1_txt         11
# dtype: int64

# %%
# After Remove the Unknown Group column, now we have 217 total groups left

# %%
# For Rest of the Variables like country_txt, weapontype1_txt, natlty1_txt,
# We are going to use Label Encoding.
# Since, There are too many categories in rest of the columns like provstate, city, target1, 
# we are going to drop those columns

# %%
data_cleaned = data_cleaned.drop(labels=['provstate', 'city', 'target1'], axis=1)

# %%
# provstate is the states of a country,
# City represents a city in a particular provstate
# Target1 represents the numerical values for targettypes,
# Dropping these columns, because of high cardinality, less relevance

# %% [markdown]
# ## Drop records with null values

# %%
data_cleaned.isnull().sum()
# Out:
# imonth                0
# iday                  0
# extended              0
# country_txt           0
# region                0
# region_txt            0
# latitude           2855
# specificity           0
# vicinity              0
# crit1                 0
# crit2                 0
# crit3                 0
# doubtterr             0
# multiple              1
# success               0
# suicide               0
# attacktype1_txt       0
# targtype1             0
# targtype1_txt         0
# natlty1_txt         810
# gname                 0
# guncertain1         374
# individual            0
# weaptype1_txt         0
# property              0
# ishostkid            63
# INT_MISC              0
# dtype: int64

# %%
data_cleaned = data_cleaned.dropna()
data_cleaned.shape
# Out:
# (100249, 27)

# %%
data_cleaned.columns.values
# Out:
# array(['imonth', 'iday', 'extended', 'country_txt', 'region',
#        'region_txt', 'latitude', 'specificity', 'vicinity', 'crit1',
#        'crit2', 'crit3', 'doubtterr', 'multiple', 'success', 'suicide',
#        'attacktype1_txt', 'targtype1', 'targtype1_txt', 'natlty1_txt',
#        'gname', 'guncertain1', 'individual', 'weaptype1_txt', 'property',
#        'ishostkid', 'INT_MISC'], dtype=object)

# %%
X_test_final.isnull().sum()
# Out:
# imonth                0
# iday                  0
# extended              0
# country_txt           0
# region                0
# region_txt            0
# provstate             0
# city                330
# latitude           1330
# specificity           0
# vicinity              0
# crit1                 0
# crit2                 0
# crit3                 0
# doubtterr             0
# multiple              2
# success               0
# suicide               0
# attacktype1_txt       0
# targtype1             0
# targtype1_txt         0
# target1             232
# natlty1_txt        1164
# gname                 0
# guncertain1           2
# individual            0
# weaptype1_txt         0
# property              0
# ishostkid            33
# INT_MISC              0
# dtype: int64

# %%
X_test_final = X_test_final.dropna()
X_test_final = X_test_final.drop(labels=['provstate', 'city', 'target1'], axis=1)
X_test_final.shape
# Out:
# (90668, 27)

# %%
X_test_final.head()
# Out:
#     imonth  iday  extended    country_txt  region      region_txt   latitude  \
# 2        1     0         0    Philippines       5  Southeast Asia  15.478598
# 3        1     0         0         Greece       8  Western Europe  37.997490
# 4        1     0         0          Japan       4       East Asia  33.580412
# 7        1     2         0  United States       1   North America  37.791927
# 12       1     8         0          Italy       8  Western Europe  41.890961
#
#     specificity  vicinity  crit1  ...  targtype1            targtype1_txt  \
# 2           4.0         0      1  ...         10      Journalists & Media
# 3           1.0         0      1  ...          7  Government (Diplomatic)
# 4           1.0         0      1  ...          7  Government (Diplomatic)
# 7           1.0         0      1  ...         21                Utilities
# 12          1.0         0      1  ...          6      Airports & Aircraft
#
#       natlty1_txt    gname  guncertain1  individual weaptype1_txt  property  \
# 2   United States  Unknown          0.0           0       Unknown         0
# 3   United States  Unknown          0.0           0    Explosives         1
# 4   United States  Unknown          0.0           0    Incendiary         1
# 7   United States  Unknown          0.0           0    Explosives         1
# 12  United States  Unknown          0.0           0      Firearms         0
#
#    ishostkid INT_MISC
# 2        0.0        1
# 3        0.0        1
# 4        0.0        1
# 7        0.0        0
# 12       0.0        1
#
# [5 rows x 27 columns]

# %%
# One Hot Encoding - Dummy Encoding

# %%
columns = ['region_txt', 'attacktype1_txt', 'targtype1_txt', 'weaptype1_txt'] # cols having categories < 30

# %%
df_encoded = pd.get_dummies(data_cleaned, columns=columns, drop_first=True, dtype=int)
df_encoded.shape
# Out:
# (100249, 73)

# %%
X_test_encoded = pd.get_dummies(X_test_final, columns=columns, drop_first=True, dtype=int)
X_test_encoded.shape
# Out:
# (90668, 74)

# %%
missing_cols = [col for col in X_test_encoded.columns if col not in df_encoded.columns]
print("Columns in X_test_encoded but not in df_encoded:\n", missing_cols)
# Out:
# Columns in X_test_encoded but not in df_encoded:
#  ['weaptype1_txt_Radiological']

# %%
X_test_encoded = X_test_encoded.drop(columns=missing_cols)

# %%
X_test_encoded.shape
# Out:
# (90668, 73)

# %%
# Ordinal Encoding Variables with more than 30 categories (High Cardinality)
# natlty1_txt, country_txt , Since these are relevent columns for prediction

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

cols = ['country_txt', 'natlty1_txt']
oe = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
df_encoded[cols] = oe.fit_transform(df_encoded[cols].astype(str))
X_test_encoded[cols] = oe.transform(X_test_encoded[cols].astype(str))

# %% [raw]
# Inference:
# test data (X_test_encoded) contains categories that were not seen during training (df_encoded). For example, 'Dominican Republic' might be present in X_test_encoded['country_txt'] but not in df_encoded['country_txt'].
#
# Problem:
# LabelEncoder cannot handle unseen categories. It raises a ValueError when it encounters a new label that wasn’t part of the fit() stage.
#
# Recommended Solution: Use sklearn's OrdinalEncoder with handle_unknown='use_encoded_value'
# OrdinalEncoder is suitable for features (X), not target variables (y).
#
# unknown_value=-1 means unseen categories in test data will be encoded as -1, preventing crashes.
#
# You can later check for -1 values in your model predictions and handle them accordingly if needed.

# %% [markdown]
# ### Encoding the Target variable
# Since, there are more than 200 categories and some models like XGBOOST only work when the variable are encoded that's why we are encoding the target variable using Label Encoder.

# %%
le_encoder = LabelEncoder()
df_encoded['gname'] = le_encoder.fit_transform(df_encoded['gname'])

# %% [markdown]
# ## Modeling

# %%
# Splitting data into independent and dependent variables
x = df_encoded.drop(columns=['gname'])
y = df_encoded['gname']

# %%
# Splitting data usingt train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=2)

# Train and Test Shape
print('Training Data: x=%s, y=%s ' % (x_train.shape, y_train.shape))
print('Test Data: x=%s, y=%s' % (x_test.shape, y_test.shape))
# Out:
# Training Data: x=(80199, 72), y=(80199,)
# Test Data: x=(20050, 72), y=(20050,)

# %%
y_train.head()
# Out:
# 196581    197
# 133561    109
# 131552      9
# 102926      9
# 34107     119
# Name: gname, dtype: int64

# %% [markdown]
# ## Base Model - LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model_lr = LogisticRegression()
model_lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
ypred_h_lr = model_lr.predict(x_test)
ypred_s_lr = model_lr.predict_proba(x_test)[:, 1]

# %%
accuracy_lr = accuracy_score(y_test, ypred_h_lr)
recall_lr = recall_score(y_test, ypred_h_lr, average='weighted')
precision_lr = precision_score(y_test, ypred_h_lr, average='weighted')

print(f'Accuracy Score LR: {accuracy_lr}')
print(f'Recall Score LR: {recall_lr}')
print(f'Precision Score LR: {precision_lr}')
# Out:
# Accuracy Score LR: 0.5245885286783042
# Recall Score LR: 0.5245885286783042
# Precision Score LR: 0.3892411784602571

# %% [markdown]
# **average='weighted':** computes recall for each class separately, then takes the average weighted by the number of true samples for each class.

# %% [markdown]
# ## DecisionTreeClassifier

# %%
model_dt = DecisionTreeClassifier(random_state=2)
model_dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=2)

# %%
ypred_h_dt = model_dt.predict(x_test)
ypred_s_dt = model_dt.predict_proba(x_test)[:, 1]

# %%
accuracy_dt = accuracy_score(y_test, ypred_h_dt)
recall_dt = recall_score(y_test, ypred_h_dt, average='weighted')
precision_dt = precision_score(y_test, ypred_h_dt, average='weighted')

print(f'Accuracy Score LR: {accuracy_dt}')
print(f'Recall Score LR: {recall_dt}')
print(f'Precision Score LR: {precision_dt}')
# Out:
# Accuracy Score LR: 0.7807980049875312
# Recall Score LR: 0.7807980049875312
# Precision Score LR: 0.7859735753350298

# %% [raw]
# # Feature Importance for Decision Tree

# %%
feature_imp = pd.DataFrame({'importances':model_dt.feature_importances_}, index=x_train.columns.to_list()).sort_values(by='importances', ascending=False)
feature_imp[feature_imp['importances'] > 0].head(12)
# Out:
#                                         importances
# latitude                                   0.312554
# country_txt                                0.251923
# iday                                       0.059985
# imonth                                     0.047866
# region_txt_Middle East & North Africa      0.029720
# region_txt_Sub-Saharan Africa              0.025100
# targtype1                                  0.022346
# region_txt_Central America & Caribbean     0.018861
# doubtterr                                  0.016940
# guncertain1                                0.016812
# region_txt_Southeast Asia                  0.016716
# property                                   0.014382

# %% [markdown]
# ### Classification Report for DecisionTree

# %%
print(classification_report(y_test, ypred_h_dt))
# Out:
#                                                                precision    recall  f1-score   support
#
#                                        Abu Sayyaf Group (ASG)       0.71      0.74      0.72       118
#                      Adan-Abyan Province of the Islamic State       0.44      0.64      0.52        11
#                      African National Congress (South Africa)       0.97      0.95      0.96       114
#                                       Al-Aqsa Martyrs Brigade       0.28      0.32      0.30        34
#                                  Al-Gama'at al-Islamiyya (IG)       0.87      0.90      0.88        51
#                                                Al-Islah Party       0.06      0.08      0.07        13
#                                               Al-Nusrah Front       0.52      0.55      0.53        53
#                                                      Al-Qaida       0.38      0.36      0.37        14
#                                              Al-Qaida in Iraq       0.58      0.58      0.58       127
#                      Al-Qaida in the Arabian Peninsula (AQAP)       0.64      0.68      0.66       222
#                        Al-Qaida in the Islamic Maghreb (AQIM)       0.36      0.33      0.34        52
#                                                    Al-Shabaab       0.98      0.97      0.98       892
#                                   Algerian Islamic Extremists       0.00      0.00      0.00         3
#                                Allied Democratic Forces (ADF)       0.81      0.82      0.82       100
#                                                    Anarchists       0.58      0.69      0.63        32
#                                 Animal Liberation Front (ALF)       0.35      0.30      0.33        23
#                        Ansar Bayt al-Maqdis (Ansar Jerusalem)       0.29      0.31      0.30        16
#                                       Ansar al-Sharia (Libya)       0.33      0.54      0.41        13
#                                   Ansar al-Sunna (Mozambique)       0.50      0.40      0.44        15
#                                      Anti-Abortion extremists       1.00      0.96      0.98        47
#                                           Anti-Balaka Militia       0.78      0.82      0.80        17
#                                    Anti-Government extremists       0.35      0.35      0.35        20
#                                        Anti-Muslim extremists       0.71      0.52      0.60        29
#                                       Anti-Semitic extremists       0.31      0.33      0.32        12
#                                              Arakan Army (AA)       0.83      0.86      0.84        22
#                         Arakan Rohingya Salvation Army (ARSA)       0.64      0.82      0.72        11
#                                     Armed Islamic Group (GIA)       0.45      0.41      0.43        44
#            Armenian Secret Army for the Liberation of Armenia       0.56      0.69      0.62        36
#                                            Asa'ib Ahl al-Haqq       0.87      0.87      0.87        15
#                                  Baloch Liberation Army (BLA)       0.44      0.42      0.43        43
#                                 Baloch Liberation Front (BLF)       0.64      0.56      0.60        41
#                                  Baloch Republican Army (BRA)       0.61      0.63      0.62        65
#                            Bangladesh Nationalist Party (BNP)       0.50      0.65      0.57        20
#                    Bangsamoro Islamic Freedom Movement (BIFM)       0.67      0.66      0.67       110
#                               Barisan Revolusi Nasional (BRN)       0.78      0.62      0.69        29
#                           Barqa Province of the Islamic State       0.59      0.58      0.58        33
#                           Basque Fatherland and Freedom (ETA)       0.94      0.93      0.93       398
#                                            Black Nationalists       0.35      0.33      0.34        18
#                                               Black September       0.70      0.67      0.68        21
#                                                Bodo Militants       0.56      0.62      0.59        16
#                                                    Boko Haram       0.95      0.96      0.95       689
#                  Central Africa Province of the Islamic State       0.48      0.63      0.55        19
#                                                Chechen Rebels       0.90      0.89      0.90        64
#                               Chukakuha (Middle Core Faction)       1.00      1.00      1.00        12
#                Communist Party of India - Maoist (CPI-Maoist)       0.61      0.66      0.63       422
#          Communist Party of Nepal - Maoist (CPN-Maoist-Chand)       0.81      0.77      0.79        60
#                                                    Communists       0.50      0.43      0.46        14
#                                   Conspiracy of Cells of Fire       0.67      0.50      0.57        12
#                                  Conspiracy theory extremists       0.92      0.85      0.88        27
#                                                       Contras       0.57      0.62      0.59        13
# Cooperative for the Development of the Congo (CODECO) militia       0.87      1.00      0.93        26
#                     Corsican National Liberation Front (FLNC)       0.95      0.89      0.92       117
#          Corsican National Liberation Front- Historic Channel       0.82      0.88      0.85        26
#                                          Corsican Separatists       0.79      0.85      0.81        13
#                                                   Death Squad       0.60      0.60      0.60        63
#          Democratic Front for the Liberation of Rwanda (FDLR)       0.50      0.58      0.54        24
#                      Democratic Revolutionary Alliance (ARDE)       0.38      0.55      0.45        20
#                                                       Dev Sol       0.68      0.64      0.66        50
#                                         Dissident Republicans       0.42      0.38      0.40        26
#                                     Donetsk People's Republic       0.92      0.84      0.88       128
#                                  Earth Liberation Front (ELF)       0.53      0.71      0.61        14
#          Ejercito Revolucionaria del Pueblo (ERP) (Argentina)       0.62      0.76      0.68        17
#              Farabundo Marti National Liberation Front (FMLN)       0.96      0.94      0.95       598
#         First of October Antifascist Resistance Group (GRAPO)       0.47      0.57      0.52        42
#                                      Free Aceh Movement (GAM)       1.00      1.00      1.00        23
#            Free Papua Movement (OPM-Organisasi Papua Merdeka)       0.76      0.72      0.74        18
#                                              Free Syrian Army       0.39      0.44      0.41        27
#                 Fuerzas Armadas de Liberacion Nacional (FALN)       0.76      0.81      0.79        16
#                                             Fulani extremists       0.91      0.87      0.89       255
#                                 Garo National Liberation Army       0.66      0.62      0.64        34
#                                  Gorkha Janmukti Morcha (GJM)       0.87      1.00      0.93        13
#                Guatemalan National Revolutionary Unity (URNG)       0.68      0.71      0.70        21
#                              Guerrilla Army of the Poor (EGP)       0.59      0.63      0.61        30
#                                                        Gunmen       0.29      0.29      0.29        55
#                       Gurkha National Liberation Front (GNLF)       0.89      0.73      0.80        11
#                           Hamas (Islamic Resistance Movement)       0.47      0.48      0.47        98
#                                               Haqqani Network       0.32      0.40      0.35        15
#                                         Hay'at Tahrir al-Sham       0.29      0.30      0.30        23
#                                                     Hezbollah       0.68      0.66      0.67        73
#                                           Hizb-ul-Ahrar (HuA)       0.07      0.08      0.07        13
#                                        Hizbul Mujahideen (HM)       0.49      0.45      0.47        56
#                               Houthi extremists (Ansar Allah)       0.89      0.88      0.88       680
#                                               Hutu extremists       0.83      0.94      0.88        31
#                            Indigenous People of Biafra (IPOB)       0.65      0.65      0.65        17
#                                             Iparretarrak (IK)       0.75      0.60      0.67        10
#                         Irish National Liberation Army (INLA)       0.04      0.04      0.04        25
#                                   Irish Republican Army (IRA)       0.82      0.82      0.82       531
#                                   Irish Republican Extremists       0.24      0.21      0.22        19
#                                 Islamic Salvation Front (FIS)       0.70      0.70      0.70        30
#                    Islamic State in the Greater Sahara (ISGS)       0.37      0.37      0.37        19
#                                   Islamic State of Iraq (ISI)       0.24      0.21      0.22        29
#                   Islamic State of Iraq and the Levant (ISIL)       0.92      0.90      0.91      1486
#                                           Islamist extremists       0.37      0.54      0.44        35
#                                              Israeli settlers       0.60      0.57      0.59        21
#                                             Jabha East Africa       0.10      0.15      0.12        13
#                                        Jaish-e-Mohammad (JeM)       0.44      0.44      0.44        27
#                    Jamaat Nusrat al-Islam wal Muslimin (JNIM)       0.60      0.52      0.56        46
#                                  Jamaat-E-Islami (Bangladesh)       0.25      0.14      0.18        14
#          Janatantrik Terai Mukti Morcha- Jwala Singh (JTMM-J)       0.56      0.60      0.58        15
#                                                     Janjaweed       0.93      0.93      0.93        44
#                                          Jemaah Islamiya (JI)       0.73      0.73      0.73        15
#                                   Jewish Defense League (JDL)       0.57      0.53      0.55        15
#                                    Jihadi-inspired extremists       0.68      0.74      0.70        34
#                                Kachin Independence Army (KIA)       0.80      1.00      0.89        12
#                                          Karen National Union       0.89      0.89      0.89        18
#                                           Kashmiri extremists       0.25      0.27      0.26        15
#                                                   Khmer Rouge       1.00      1.00      1.00        22
#                         Khorasan Chapter of the Islamic State       0.41      0.44      0.42       128
#                                  Kosovo Liberation Army (KLA)       1.00      0.82      0.90        11
#                                Kurdistan Workers' Party (PKK)       0.91      0.92      0.91       494
#                                    Lashkar-e-Islam (Pakistan)       0.47      0.32      0.38        25
#                                             Lashkar-e-Jhangvi       0.40      0.34      0.37        29
#                                         Lashkar-e-Taiba (LeT)       0.49      0.47      0.48        51
#                                          Left-Wing Guerrillas       0.62      0.50      0.56        20
#                                           Left-Wing Militants       0.51      0.56      0.54        34
#                       Liberation Tigers of Tamil Eelam (LTTE)       0.89      0.83      0.86       309
#                                  Lord's Resistance Army (LRA)       0.91      0.92      0.92        66
#                                     Luhansk People's Republic       0.64      0.79      0.71        43
#                                   M-19 (Movement of April 19)       0.44      0.48      0.46       106
#                       Manuel Rodriguez Patriotic Front (FPMR)       0.85      0.80      0.82       162
#                                                       Maoists       0.67      0.62      0.64       432
#                                            Mapuche extremists       1.00      0.94      0.97        16
#                                                     Mayi Mayi       0.65      0.39      0.49        33
#                                                     Militants       0.15      0.20      0.17        15
#                                        Montoneros (Argentina)       0.81      0.74      0.77        23
#                          Moro Islamic Liberation Front (MILF)       0.40      0.49      0.44        72
#                         Moro National Liberation Front (MNLF)       0.37      0.40      0.38        35
#       Movement for the Emancipation of the Niger Delta (MEND)       0.73      0.73      0.73        15
#                    Movement of Democratic Forces of Casamance       0.92      1.00      0.96        11
#              Movement of the Revolutionary Left (MIR) (Chile)       0.72      0.69      0.71        61
#                 Mozambique National Resistance Movement (MNR)       0.93      0.96      0.95        57
#                                       Mujahedin-e Khalq (MEK)       0.77      0.81      0.79        21
#                                            Muslim Brotherhood       0.63      0.65      0.64        26
#                                        Muslim Fundamentalists       0.25      0.19      0.21        16
#                                              Muslim Militants       0.47      0.50      0.48        58
#                                            Muslim Separatists       0.51      0.75      0.61        32
#                                             Muslim extremists       0.38      0.39      0.39       191
#                                 Muttahida Qami Movement (MQM)       0.71      0.83      0.76        35
#                                              Narco-Terrorists       0.68      0.78      0.73        73
#                  National Democratic Front of Bodoland (NDFB)       0.63      0.54      0.58        35
#                    National Liberation Army of Colombia (ELN)       0.60      0.57      0.58       346
#                   National Liberation Front of Tripura (NLFT)       0.36      0.31      0.33        16
#  National Socialist Council of Nagaland-Isak-Muivah (NSCN-IM)       0.23      0.14      0.18        21
#      National Socialist Council of Nagaland-Khaplang (NSCN-K)       0.33      0.50      0.40        14
#   National Union for the Total Independence of Angola (UNITA)       0.96      0.96      0.96        80
#                                                     Naxalites       0.11      0.08      0.09        13
#                                           Neo-Nazi extremists       0.78      0.75      0.76        51
#                                       New People's Army (NPA)       0.91      0.88      0.89       634
#                             New World Liberation Front (NWLF)       0.65      0.81      0.72        16
#                             Nicaraguan Democratic Force (FDN)       0.80      0.67      0.73       135
#                                         Nicaraguan Resistance       0.36      0.43      0.40        37
#                November 17 Revolutionary Organization (N17RO)       0.75      0.55      0.63        22
#                                              Opposition Group       0.78      0.74      0.76        19
#                       Palestine Liberation Organization (PLO)       0.39      0.42      0.41        33
#                                        Palestinian Extremists       0.76      0.72      0.74       116
#                               Palestinian Islamic Jihad (PIJ)       0.36      0.36      0.36        45
#                                                  Palestinians       0.75      0.74      0.75       216
#                                Paraguayan People's Army (EPP)       1.00      1.00      1.00        15
#                              People's Liberation Army (India)       0.73      0.42      0.53        19
#                              People's Liberation Forces (FPL)       0.37      0.53      0.44        32
#                               People's Liberation Front (JVP)       0.73      0.82      0.78        84
#                            People's Liberation Front of India       0.10      0.18      0.13        17
#                               People's Protection Units (YPG)       0.45      0.38      0.42        13
#               People's Revolutionary Army (ERP) (El Salvador)       0.44      0.33      0.38        12
#                                      People's War Group (PWG)       0.31      0.42      0.36        19
#          Popular Front for the Liberation of Palestine (PFLP)       0.08      0.07      0.07        30
#                                 Popular Liberation Army (EPL)       0.23      0.22      0.22        55
#                                                   Prima Linea       0.25      0.27      0.26        11
#                                          Pro Hartal Activists       0.75      0.67      0.71        18
#                                         Protestant extremists       0.42      0.37      0.39        67
#                                                     Recontras       0.20      0.27      0.23        11
#                                        Red Army Faction (RAF)       0.53      0.62      0.57        13
#                                                  Red Brigades       0.73      0.77      0.75        43
#                                                    Resistenza       0.83      1.00      0.91        15
#                 Revolutionary Armed Forces of Colombia (FARC)       0.62      0.60      0.61       466
#      Revolutionary Armed Forces of Colombia (FARC) dissidents       0.27      0.32      0.29        44
#                                           Revolutionary Cells       0.78      0.58      0.67        12
#           Revolutionary Organization of People in Arms (ORPA)       0.50      0.59      0.54        22
#                         Revolutionary People's Struggle (ELA)       0.59      0.76      0.67        17
#                              Revolutionary United Front (RUF)       1.00      0.83      0.91        12
#                         Ricardo Franco Front (Dissident FARC)       0.55      0.50      0.52        12
#                                         Right-wing extremists       0.58      0.67      0.62        21
#                                    Runda Kumpulan Kecil (RKK)       0.62      0.52      0.56        31
#              Salafist Group for Preaching and Fighting (GSPC)       0.34      0.38      0.36        40
#                   Sandinista National Liberation Front (FSLN)       0.61      0.64      0.62        39
#                                                   Separatists       0.72      0.74      0.73       187
#                                   Shanti Bahini - Peace Force       0.75      0.69      0.72        13
#                                             Shining Path (SL)       0.95      0.96      0.95       862
#                                               Sikh Extremists       0.90      0.86      0.88       134
#             Simon Bolivar Guerrilla Coordinating Board (CGSB)       0.37      0.41      0.38        37
#                           Sinai Province of the Islamic State       0.83      0.83      0.83       113
#                            Sindhu Desh Liberation Army (SDLA)       0.77      0.83      0.80        12
#               South-West Africa People's Organization (SWAPO)       0.78      0.70      0.74        10
#                            Southern Mobility Movement (Yemen)       0.33      0.23      0.27        13
#                                              Student Radicals       0.55      0.73      0.63        15
#                    Sudan People's Liberation Movement - North       0.85      0.92      0.88        12
#    Sudan People's Liberation Movement in Opposition (SPLM-IO)       1.00      0.86      0.92        28
#                                                       Taliban       0.97      0.96      0.97      2505
#                                                        Tamils       0.45      0.46      0.46        39
#                               Tehrik-i-Taliban Pakistan (TTP)       0.77      0.76      0.76       301
#                                                  Terra Lliure       0.88      0.58      0.70        12
#                                                    Terrorists       0.40      0.22      0.29         9
#                                        Thai Islamic Militants       0.43      0.55      0.48        11
#                                             The Extraditables       0.64      0.64      0.64        22
#                                 The New Irish Republican Army       0.30      0.50      0.38        14
#                                                     Tribesmen       0.31      0.31      0.31        32
#                         Tripoli Province of the Islamic State       0.95      0.83      0.89        72
#                     Tupac Amaru Revolutionary Movement (MRTA)       0.64      0.60      0.62       109
#                              Turkish People's Liberation Army       0.64      0.64      0.64        14
#                                            Uighur Separatists       1.00      0.94      0.97        17
#                                 Ulster Freedom Fighters (UFF)       0.28      0.32      0.30        53
#                                  Ulster Volunteer Force (UVF)       0.17      0.15      0.16        54
#                                      United Baloch Army (UBA)       0.41      0.61      0.49        18
#                       United Liberation Front of Assam (ULFA)       0.70      0.73      0.72        79
#                                United Popular Action Movement       0.32      0.50      0.39        22
#                   United Self Defense Units of Colombia (AUC)       0.06      0.08      0.07        13
#                               White supremacists/nationalists       0.38      0.38      0.38        29
#
#                                                      accuracy                           0.78     20050
#                                                     macro avg       0.60      0.60      0.60     20050
#                                                  weighted avg       0.79      0.78      0.78     20050

# %% [markdown]
# ## RandomForestClassifier

# %%
model_rf = RandomForestClassifier(n_estimators=200, random_state=2)
model_rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=2)

# %%
ypred_h_rf = model_rf.predict(x_test)

# %%
accuracy_rf = accuracy_score(y_test, ypred_h_rf)
recall_rf = recall_score(y_test, ypred_h_rf, average='weighted')
precision_rf = precision_score(y_test, ypred_h_rf, average='weighted')

print(f'Accuracy Score LR: {accuracy_rf}')
print(f'Recall Score LR: {recall_rf}')
print(f'Precision Score LR: {precision_rf}')
# Out:
# Accuracy Score LR: 0.8166084788029925
# Recall Score LR: 0.8166084788029925
# Precision Score LR: 0.806762092782474

# %% [markdown]
# ### Classification Report for RandomForest

# %%
print(classification_report(y_test, ypred_h_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.72      0.70       118
#            1       0.67      0.18      0.29        11
#            2       0.93      0.98      0.96       114
#            3       0.33      0.32      0.33        34
#            4       0.91      0.96      0.93        51
#            5       0.67      0.15      0.25        13
#            6       0.79      0.43      0.56        53
#            7       1.00      0.29      0.44        14
#            8       0.86      0.49      0.62       127
#            9       0.69      0.69      0.69       222
#           10       0.48      0.38      0.43        52
#           11       0.96      1.00      0.98       892
#           12       0.00      0.00      0.00         3
#           13       0.70      0.87      0.77       100
#           14       0.84      0.66      0.74        32
#           15       0.29      0.17      0.22        23
#           16       0.00      0.00      0.00        16
#           17       0.40      0.31      0.35        13
#           18       0.67      0.53      0.59        15
#           19       0.94      0.96      0.95        47
#           20       0.74      0.82      0.78        17
#           21       0.91      0.50      0.65        20
#           22       0.70      0.55      0.62        29
#           23       0.67      0.33      0.44        12
#           24       0.79      0.86      0.83        22
#           25       0.75      0.82      0.78        11
#           26       0.51      0.59      0.55        44
#           27       0.63      0.81      0.71        36
#           28       1.00      0.87      0.93        15
#           29       0.47      0.33      0.38        43
#           30       0.50      0.61      0.55        41
#           31       0.66      0.69      0.68        65
#           32       0.68      0.65      0.67        20
#           33       0.76      0.67      0.71       110
#           34       0.90      0.62      0.73        29
#           35       0.53      0.58      0.55        33
#           36       0.92      0.97      0.94       398
#           37       0.75      0.50      0.60        18
#           38       0.93      0.67      0.78        21
#           39       0.50      0.38      0.43        16
#           40       0.94      0.98      0.96       689
#           41       0.64      0.47      0.55        19
#           42       0.88      0.95      0.92        64
#           43       1.00      1.00      1.00        12
#           44       0.66      0.72      0.69       422
#           45       0.83      0.83      0.83        60
#           46       1.00      0.36      0.53        14
#           47       0.33      0.33      0.33        12
#           48       0.96      0.85      0.90        27
#           49       0.62      0.38      0.48        13
#           50       0.72      0.69      0.71        26
#           51       0.85      0.97      0.90       117
#           52       1.00      0.88      0.94        26
#           53       0.92      0.85      0.88        13
#           54       0.69      0.68      0.69        63
#           55       0.67      0.33      0.44        24
#           56       0.50      0.55      0.52        20
#           57       0.97      0.68      0.80        50
#           58       0.54      0.54      0.54        26
#           59       0.83      0.95      0.89       128
#           60       0.45      0.64      0.53        14
#           61       0.60      0.53      0.56        17
#           62       0.94      0.98      0.96       598
#           63       0.70      0.45      0.55        42
#           64       0.86      0.83      0.84        23
#           65       0.80      0.89      0.84        18
#           66       0.62      0.48      0.54        27
#           67       0.87      0.81      0.84        16
#           68       0.93      0.93      0.93       255
#           69       0.56      0.65      0.60        34
#           70       0.93      1.00      0.96        13
#           71       0.85      0.81      0.83        21
#           72       0.69      0.73      0.71        30
#           73       0.58      0.33      0.42        55
#           74       1.00      0.73      0.84        11
#           75       0.49      0.49      0.49        98
#           76       0.80      0.27      0.40        15
#           77       0.70      0.30      0.42        23
#           78       0.70      0.64      0.67        73
#           79       0.33      0.15      0.21        13
#           80       0.40      0.41      0.41        56
#           81       0.88      0.94      0.91       680
#           82       0.96      0.87      0.92        31
#           83       0.90      0.53      0.67        17
#           84       0.67      0.40      0.50        10
#           85       0.17      0.04      0.06        25
#           86       0.81      0.94      0.87       531
#           87       0.20      0.05      0.08        19
#           88       0.70      0.70      0.70        30
#           89       1.00      0.37      0.54        19
#           90       0.57      0.28      0.37        29
#           91       0.89      0.97      0.93      1486
#           92       0.55      0.60      0.58        35
#           93       0.75      0.71      0.73        21
#           94       0.00      0.00      0.00        13
#           95       0.48      0.41      0.44        27
#           96       0.64      0.54      0.59        46
#           97       0.45      0.36      0.40        14
#           98       0.91      0.67      0.77        15
#           99       0.91      0.98      0.95        44
#          100       0.92      0.73      0.81        15
#          101       0.56      0.67      0.61        15
#          102       0.73      0.79      0.76        34
#          103       0.67      0.67      0.67        12
#          104       0.81      0.72      0.76        18
#          105       0.50      0.27      0.35        15
#          106       1.00      1.00      1.00        22
#          107       0.67      0.23      0.35       128
#          108       0.82      0.82      0.82        11
#          109       0.91      0.95      0.93       494
#          110       0.57      0.16      0.25        25
#          111       0.43      0.34      0.38        29
#          112       0.40      0.49      0.44        51
#          113       0.91      0.50      0.65        20
#          114       0.69      0.65      0.67        34
#          115       0.88      0.96      0.92       309
#          116       0.88      0.85      0.86        66
#          117       0.77      0.47      0.58        43
#          118       0.56      0.46      0.51       106
#          119       0.76      0.85      0.80       162
#          120       0.67      0.75      0.71       432
#          121       0.94      1.00      0.97        16
#          122       0.57      0.39      0.46        33
#          123       0.33      0.07      0.11        15
#          124       0.69      0.78      0.73        23
#          125       0.53      0.35      0.42        72
#          126       0.50      0.31      0.39        35
#          127       1.00      0.53      0.70        15
#          128       0.92      1.00      0.96        11
#          129       0.75      0.59      0.66        61
#          130       0.82      0.98      0.90        57
#          131       0.88      0.67      0.76        21
#          132       0.67      0.54      0.60        26
#          133       0.56      0.31      0.40        16
#          134       0.70      0.55      0.62        58
#          135       0.79      0.72      0.75        32
#          136       0.63      0.45      0.52       191
#          137       0.85      0.83      0.84        35
#          138       0.78      0.77      0.77        73
#          139       0.56      0.26      0.35        35
#          140       0.61      0.63      0.62       346
#          141       0.67      0.12      0.21        16
#          142       0.33      0.14      0.20        21
#          143       0.70      0.50      0.58        14
#          144       0.97      0.97      0.97        80
#          145       0.20      0.08      0.11        13
#          146       0.79      0.73      0.76        51
#          147       0.85      0.94      0.90       634
#          148       0.59      0.81      0.68        16
#          149       0.73      0.84      0.78       135
#          150       0.33      0.19      0.24        37
#          151       0.59      0.45      0.51        22
#          152       0.86      0.63      0.73        19
#          153       0.58      0.45      0.51        33
#          154       0.77      0.79      0.78       116
#          155       0.42      0.38      0.40        45
#          156       0.74      0.82      0.78       216
#          157       1.00      1.00      1.00        15
#          158       0.91      0.53      0.67        19
#          159       0.67      0.31      0.43        32
#          160       0.88      0.82      0.85        84
#          161       0.29      0.12      0.17        17
#          162       0.56      0.38      0.45        13
#          163       0.60      0.25      0.35        12
#          164       0.67      0.21      0.32        19
#          165       0.17      0.07      0.10        30
#          166       0.38      0.15      0.21        55
#          167       0.30      0.27      0.29        11
#          168       0.80      0.89      0.84        18
#          169       0.52      0.39      0.44        67
#          170       0.57      0.36      0.44        11
#          171       0.69      0.69      0.69        13
#          172       0.76      0.88      0.82        43
#          173       1.00      1.00      1.00        15
#          174       0.63      0.77      0.70       466
#          175       0.53      0.20      0.30        44
#          176       0.62      0.67      0.64        12
#          177       0.58      0.64      0.61        22
#          178       0.43      0.71      0.53        17
#          179       1.00      0.83      0.91        12
#          180       0.86      0.50      0.63        12
#          181       0.87      0.62      0.72        21
#          182       0.89      0.52      0.65        31
#          183       0.47      0.50      0.48        40
#          184       0.62      0.72      0.67        39
#          185       0.72      0.82      0.77       187
#          186       0.69      0.85      0.76        13
#          187       0.94      0.99      0.96       862
#          188       0.79      0.93      0.85       134
#          189       0.56      0.38      0.45        37
#          190       0.76      0.96      0.85       113
#          191       0.73      0.67      0.70        12
#          192       1.00      0.60      0.75        10
#          193       0.50      0.23      0.32        13
#          194       0.69      0.73      0.71        15
#          195       1.00      0.92      0.96        12
#          196       0.96      0.89      0.93        28
#          197       0.96      0.99      0.98      2505
#          198       0.87      0.33      0.48        39
#          199       0.70      0.89      0.79       301
#          200       0.80      0.33      0.47        12
#          201       1.00      0.22      0.36         9
#          202       0.80      0.36      0.50        11
#          203       0.76      0.59      0.67        22
#          204       0.67      0.29      0.40        14
#          205       0.54      0.22      0.31        32
#          206       0.81      0.85      0.83        72
#          207       0.83      0.54      0.66       109
#          208       0.73      0.79      0.76        14
#          209       1.00      1.00      1.00        17
#          210       0.36      0.30      0.33        53
#          211       0.20      0.17      0.18        54
#          212       0.60      0.50      0.55        18
#          213       0.71      0.76      0.73        79
#          214       0.29      0.32      0.30        22
#          215       0.33      0.08      0.12        13
#          216       0.42      0.52      0.46        29
#
#     accuracy                           0.82     20050
#    macro avg       0.69      0.59      0.62     20050
# weighted avg       0.81      0.82      0.80     20050

# %%
# grid_rf = {'n_estimators': [200, 300], 
#            'max_depth': [12, 14], 
#            'min_samples_split': [2, 5],
#            'min_samples_leaf': [1, 2]}

# gscv_rf = GridSearchCV(estimator=RandomForestClassifier(), 
#                        param_grid=grid_rf, 
#                        scoring='accuracy', 
#                        cv=10, 
#                        n_jobs=-1)
# gscv_rf.fit(x_train, y_train)

# %%
# best_estimator = gscv_rf.best_estimator_
# best_score = gscv_rf.best_score_
# best_params = gscv_rf.best_params_

# print('Best Score : ', best_score)
# print('Best Params: \n', best_params)

# %% [markdown]
# ### Note:
# Tried to use GridSearchCV to find the best params for RandomForest model,
# However, Our System is not powerful enough to run those combinations for such a large data.

# %% [markdown]
# ## AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
model_ada = AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=12, random_state=42), n_estimators=250, learning_rate=0.9)
model_ada.fit(x_train, y_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=12,
#                                                     random_state=42),
#                    learning_rate=0.9, n_estimators=250)

# %%
ypred_ada = model_ada.predict(x_test)

# %%
accuracy_ada = accuracy_score(y_test, ypred_ada)
recall_ada = recall_score(y_test, ypred_ada, average='weighted')
precision_ada = precision_score(y_test, ypred_ada, average='weighted')

print(f'Accuracy Score LR: {accuracy_ada}')
print(f'Recall Score LR: {recall_ada}')
print(f'Precision Score LR: {precision_ada}')
# Out:
# Accuracy Score LR: 0.8097755610972569
# Recall Score LR: 0.8097755610972569
# Precision Score LR: 0.807048341901352

# %% [markdown]
# ## Creating a Metrics DataFrame for the Models

# %%
# Initialize an empty list to collect all model metrics
metrics = []

# Define a helper function to evaluate and store metrics
def evaluate_model(name, y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred, average='weighted') # weighted: accounts for class imbalance (more realistic for many datasets).
    precision = precision_score(y_true, y_pred, average='weighted') 
    
    metrics.append({
        'Model': name,
        'Accuracy': round(accuracy, 4),
        'Recall': round(recall, 4),
        'Precision': round(precision, 4)
    })

# Evaluate and store metrics
evaluate_model("Logistic Regression", y_test, ypred_h_lr)
evaluate_model("Decision Tree", y_test, ypred_h_dt)
evaluate_model("Random Forest", y_test, ypred_h_rf)
evaluate_model('AdaBoost', y_test, ypred_ada)

# %%
# Convert to DataFrame
metrics_df = pd.DataFrame(metrics).sort_values(by='Accuracy', ascending=False)

# Display metrics
print(metrics_df)
# Out:
#                  Model  Accuracy  Recall  Precision
# 2        Random Forest    0.8166  0.8166     0.8068
# 3             AdaBoost    0.8098  0.8098     0.8070
# 1        Decision Tree    0.7808  0.7808     0.7860
# 0  Logistic Regression    0.5246  0.5246     0.3892

# %% [raw]
# Since, we get the best score using RandomForestClassifier
# We are going to use this model to predict the test data on unknown groupnames

# %% [markdown]
# ## Predicting Unknown gnames using Test Data

# %%
ypred_h_fin = model_rf.predict(X_test_encoded.drop(columns=['gname']))

# %%
ypred_h_fin[:10]
# Out:
# array([147, 178,  43, 148,  38,  62, 147, 146,  37,  60])

# %%
group_names = le_encoder.inverse_transform(ypred_h_fin)

# %%
X_test_encoded['Predicted_gnames'] = ypred_h_fin

# %%
# Count frequency of each predicted group
unique, counts = np.unique(ypred_h_fin, return_counts=True)

# %%
# Create DataFrame for readability
pred_counts = pd.DataFrame({'Encoded': unique, 'Count': counts})

# %%
# Add original group names
pred_counts['Group'] = le_encoder.inverse_transform(pred_counts['Encoded'])

# %%
# Sort and take top 10
top_10_active_groups = pred_counts.sort_values(by='Count', ascending=False).head(10)
print(top_10_active_groups)
# Out:
#      Encoded  Count                                             Group
# 91        91  20330       Islamic State of Iraq and the Levant (ISIL)
# 199      199   7149                   Tehrik-i-Taliban Pakistan (TTP)
# 197      197   6484                                           Taliban
# 185      185   2615                                       Separatists
# 147      147   2253                           New People's Army (NPA)
# 11        11   1928                                        Al-Shabaab
# 42        42   1842                                    Chechen Rebels
# 2          2   1245          African National Congress (South Africa)
# 62        62   1229  Farabundo Marti National Liberation Front (FMLN)
# 73        73   1228                                            Gunmen

# %%
top_10_active_groups
# Out:
#      Encoded  Count                                             Group
# 91        91  20330       Islamic State of Iraq and the Levant (ISIL)
# 199      199   7149                   Tehrik-i-Taliban Pakistan (TTP)
# 197      197   6484                                           Taliban
# 185      185   2615                                       Separatists
# 147      147   2253                           New People's Army (NPA)
# 11        11   1928                                        Al-Shabaab
# 42        42   1842                                    Chechen Rebels
# 2          2   1245          African National Congress (South Africa)
# 62        62   1229  Farabundo Marti National Liberation Front (FMLN)
# 73        73   1228                                            Gunmen

# %%
# Visualising the top 10 Most active groups by Frequency of Attacks

# %%
plt.figure(figsize=(12,6))
sns.barplot(
    data=top_10_active_groups,
    x='Group', y='Count',
    palette='viridis'
)
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 Predicted Groups by Frequency', fontsize=14)
plt.xlabel('Group Name', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()
